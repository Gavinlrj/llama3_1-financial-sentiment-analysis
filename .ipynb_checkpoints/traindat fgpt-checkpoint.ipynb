# %%
from datasets import load_dataset

ds = load_dataset("FinGPT/fingpt-sentiment-train")
# Out:
# ...
# Generating train split:   0%|          | 0/76772 [00:00<?, ? examples/s]

# %%
pip install datasets
# Out:
# ...
#    ---------------------------------------- 0.0/233.0 kB ? eta -:--:--
#    ------------------------ --------------- 143.4/233.0 kB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 233.0/233.0 kB 3.6 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/1.6 MB ? eta -:--:--
#    ----- ---------------------------------- 0.2/1.6 MB 6.7 MB/s eta 0:00:01
#    ------------ --------------------------- 0.5/1.6 MB 6.0 MB/s eta 0:00:01
#    ---------------- ----------------------- 0.7/1.6 MB 5.2 MB/s eta 0:00:01
#    -------------------------- ------------- 1.1/1.6 MB 6.2 MB/s eta 0:00:01
#    ------------------------------------ --- 1.5/1.6 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.6/1.6 MB 6.3 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/78.6 kB ? eta -:--:--
#    ---------------------------------------- 78.6/78.6 kB 2.2 MB/s eta 0:00:00
# ...
#   Attempting uninstall: sqlalchemy
# ...
